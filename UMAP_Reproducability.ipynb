# %% [markdown]
# <a href="https://colab.research.google.com/github/sonalimp29/UMAP-/blob/main/UMAP_Reproducability.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import sklearn.datasets
import umap
import umap.plot

# %%
data, labels = sklearn.datasets.fetch_openml(
    'mnist_784', version=1, return_X_y=True
)

# %%
# %%time
mapper1 = umap.UMAP().fit(data)
# Out:
# CPU times: user 3min 6s, sys: 3.43 s, total: 3min 10s
# Wall time: 1min 57s

# %%
umap.plot.points(mapper1, labels=labels)

# %%
# %%time
mapper2 = umap.UMAP().fit(data)
# Out:
# CPU times: user 2min 44s, sys: 4.11 s, total: 2min 48s
# Wall time: 1min 30s

# %%
umap.plot.points(mapper2, labels=labels)

# %%
# %%time
mapper3 = umap.UMAP(random_state=42).fit(data)
# Out:
# CPU times: user 2min 17s, sys: 3.37 s, total: 2min 20s
# Wall time: 2min

# %%
umap.plot.points(mapper3, labels=labels)

# %%
# %%time
mapper4 = umap.UMAP(random_state=42).fit(data)
# Out:
# CPU times: user 2min 19s, sys: 3.17 s, total: 2min 22s
# Wall time: 2min 1s

# %%
umap.plot.points(mapper4, labels=labels)

# %%
np.all(mapper3.embedding_ == mapper4.embedding_)
# Out:
# True
